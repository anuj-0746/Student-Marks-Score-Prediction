# %%
import pandas as pd
df=pd.read_csv("student_habits_performance.csv")

# %%
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
# 2         Poor                   1              High School             Poor
# 3         Poor                   4                   Master             Good
# 4         Fair                   3                   Master             Good
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0
# 2                     1                            No        34.3
# 3                     1                           Yes        26.8
# 4                     1                            No        66.4

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   str
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   str
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   str
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   str
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    str
#  12  internet_quality               1000 non-null   str
#  13  mental_health_rating           1000 non-null   int64
#  14  extracurricular_participation  1000 non-null   str
#  15  exam_score                     1000 non-null   float64
# dtypes: float64(6), int64(3), str(7)
# memory usage: 156.3 KB

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.head(2)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
df.isna().sum().sum()
# Out:
# np.int64(91)

# %%
df.dropna()
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0              1.1            No                   85.0          8.0
# 1              2.3            No                   97.3          4.6
# 2              1.3            No                   94.8          8.0
# 3              1.0            No                   71.0          9.2
# 4              0.5            No                   90.9          4.9
# ..             ...           ...                    ...          ...
# 995            1.6            No                   77.0          7.5
# 996            2.4           Yes                   86.0          6.8
# 997            1.3            No                   61.9          6.5
# 998            1.1           Yes                  100.0          7.6
# 999            1.9            No                   89.4          7.1
#
#     diet_quality  exercise_frequency parental_education_level  \
# 0           Fair                   6                   Master
# 1           Good                   6              High School
# 2           Poor                   1              High School
# 3           Poor                   4                   Master
# 4           Fair                   3                   Master
# ..           ...                 ...                      ...
# 995         Fair                   2              High School
# 996         Poor                   1              High School
# 997         Good                   5                 Bachelor
# 998         Fair                   0                 Bachelor
# 999         Good                   2                 Bachelor
#
#     internet_quality  mental_health_rating extracurricular_participation  \
# 0            Average                     8                           Yes
# 1            Average                     8                            No
# 2               Poor                     1                            No
# 3               Good                     1                           Yes
# 4               Good                     1                            No
# ..               ...                   ...                           ...
# 995             Good                     6                           Yes
# 996          Average                     6                           Yes
# 997             Good                     9                           Yes
# 998          Average                     1                            No
# 999          Average                     8                            No
#
#      exam_score
# 0          56.2
# 1         100.0
# 2          34.3
# 3          26.8
# 4          66.4
# ..          ...
# 995        76.1
# 996        65.9
# 997        64.4
# 998        69.7
# 999        74.9
#
# [909 rows x 16 columns]

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0              1.1            No                   85.0          8.0
# 1              2.3            No                   97.3          4.6
# 2              1.3            No                   94.8          8.0
# 3              1.0            No                   71.0          9.2
# 4              0.5            No                   90.9          4.9
# ..             ...           ...                    ...          ...
# 995            1.6            No                   77.0          7.5
# 996            2.4           Yes                   86.0          6.8
# 997            1.3            No                   61.9          6.5
# 998            1.1           Yes                  100.0          7.6
# 999            1.9            No                   89.4          7.1
#
#     diet_quality  exercise_frequency parental_education_level  \
# 0           Fair                   6                   Master
# 1           Good                   6              High School
# 2           Poor                   1              High School
# 3           Poor                   4                   Master
# 4           Fair                   3                   Master
# ..           ...                 ...                      ...
# 995         Fair                   2              High School
# 996         Poor                   1              High School
# 997         Good                   5                 Bachelor
# 998         Fair                   0                 Bachelor
# 999         Good                   2                 Bachelor
#
#     internet_quality  mental_health_rating extracurricular_participation  \
# 0            Average                     8                           Yes
# 1            Average                     8                            No
# 2               Poor                     1                            No
# 3               Good                     1                           Yes
# 4               Good                     1                            No
# ..               ...                   ...                           ...
# 995             Good                     6                           Yes
# 996          Average                     6                           Yes
# 997             Good                     9                           Yes
# 998          Average                     1                            No
# 999          Average                     8                            No
#
#      exam_score
# 0          56.2
# 1         100.0
# 2          34.3
# 3          26.8
# 4          66.4
# ..          ...
# 995        76.1
# 996        65.9
# 997        64.4
# 998        69.7
# 999        74.9
#
# [909 rows x 16 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#               age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  909.000000           909.000000          909.000000     909.000000
# mean    20.475248             3.538724            2.504620       1.830363
# std      2.302721             1.469730            1.164802       1.071251
# min     17.000000             0.000000            0.000000       0.000000
# 25%     18.000000             2.500000            1.700000       1.000000
# 50%     20.000000             3.500000            2.500000       1.800000
# 75%     22.000000             4.500000            3.300000       2.600000
# max     24.000000             8.300000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count             909.000000   909.000000          909.000000
# mean               83.880308     6.474037            3.051705
# std                 9.453622     1.218943            2.035632
# min                56.000000     3.200000            0.000000
# 25%                77.500000     5.600000            1.000000
# 50%                84.200000     6.500000            3.000000
# 75%                90.700000     7.300000            5.000000
# max               100.000000    10.000000            6.000000
#
#        mental_health_rating  exam_score
# count            909.000000  909.000000
# mean               5.466447   69.558196
# std                2.857525   16.929436
# min                1.000000   18.400000
# 25%                3.000000   58.400000
# 50%                5.000000   70.400000
# 75%                8.000000   81.300000
# max               10.000000  100.000000

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df.describe(include="object")
# Out:
#        student_id gender part_time_job diet_quality parental_education_level  \
# count         909    909           909          909                      909
# unique        909      3             2            3                        3
# top         S1000   Male            No         Fair              High School
# freq            1    440           713          396                      392
#
#        internet_quality extracurricular_participation
# count               909                           909
# unique                3                             2
# top                Good                            No
# freq                410                           620

# %%
categorical_cols= ['gender', 'part_time_job', 'diet_quality',
       'parental_education_level', 'internet_quality',
       'extracurricular_participation']

# %%
for col in categorical_cols:
    print(f"Value counts for {col}: \n {df[col].value_counts()}")
# Out:
# Value counts for gender:
#  gender
# Male      440
# Female    433
# Other      36
# Name: count, dtype: int64
# Value counts for part_time_job:
#  part_time_job
# No     713
# Yes    196
# Name: count, dtype: int64
# Value counts for diet_quality:
#  diet_quality
# Fair    396
# Good    347
# Poor    166
# Name: count, dtype: int64
# Value counts for parental_education_level:
#  parental_education_level
# High School    392
# Bachelor       350
# Master         167
# Name: count, dtype: int64
# Value counts for internet_quality:
#  internet_quality
# Good       410
# Average    352
# Poor       147
# Name: count, dtype: int64
# Value counts for extracurricular_participation:
#  extracurricular_participation
# No     620
# Yes    289
# Name: count, dtype: int64

# %%
df.hist(bins=20, edgecolor='black')
plt.tight_layout()
plt.show()

# %%
for col in categorical_cols:
    sns.countplot(data=df, x=col)
    plt.title(f"Distribution of {col}")
    plt.xticks(rotation=45)
    plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                             age  study_hours_per_day  social_media_hours  \
# age                    1.000000             0.007150           -0.023854
# study_hours_per_day    0.007150             1.000000            0.007364
# social_media_hours    -0.023854             0.007364            1.000000
# netflix_hours          0.005841            -0.014493            0.011865
# attendance_percentage -0.030203             0.028967            0.049356
# sleep_hours            0.040498            -0.026241            0.026861
# exercise_frequency    -0.005718            -0.024708           -0.023975
# mental_health_rating  -0.052137            -0.015896           -0.000417
# exam_score            -0.012833             0.822950           -0.171672
#
#                        netflix_hours  attendance_percentage  sleep_hours  \
# age                         0.005841              -0.030203     0.040498
# study_hours_per_day        -0.014493               0.028967    -0.026241
# social_media_hours          0.011865               0.049356     0.026861
# netflix_hours               1.000000              -0.015008    -0.017006
# attendance_percentage      -0.015008               1.000000     0.001972
# sleep_hours                -0.017006               0.001972     1.000000
# exercise_frequency         -0.004155              -0.010563     0.030013
# mental_health_rating       -0.016612              -0.017096    -0.010653
# exam_score                 -0.166578               0.096005     0.122294
#
#                        exercise_frequency  mental_health_rating  exam_score
# age                             -0.005718             -0.052137   -0.012833
# study_hours_per_day             -0.024708             -0.015896    0.822950
# social_media_hours              -0.023975             -0.000417   -0.171672
# netflix_hours                   -0.004155             -0.016612   -0.166578
# attendance_percentage           -0.010563             -0.017096    0.096005
# sleep_hours                      0.030013             -0.010653    0.122294
# exercise_frequency               1.000000             -0.001500    0.161397
# mental_health_rating            -0.001500              1.000000    0.317945
# exam_score                       0.161397              0.317945    1.000000

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
df.describe().columns

# %%
num_features = ['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
       'attendance_percentage', 'sleep_hours', 'exercise_frequency',
       'mental_health_rating']

# %%
for feature in num_features:
    sns.scatterplot(data=df, x=feature, y='exam_score')
    plt.title(f"{feature} vs Exam Score")
    plt.show()

# %%
for col in categorical_cols:
    sns.boxplot(data=df, x=col, y='exam_score')
    plt.title(f"Exam Score by {col}")
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# Feature Engineering in ML Model:

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='str')

# %%
df.head(2)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0

# %%
features = ['study_hours_per_day', 'attendance_percentage', 'mental_health_rating', 'sleep_hours','part_time_job' ]

# %%
target = 'exam_score'

# %%
df_model = df[features + [target]].copy()

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  mental_health_rating  \
# 0                    0.0                   85.0                     8
# 1                    6.9                   97.3                     8
# 2                    1.4                   94.8                     1
# 3                    1.0                   71.0                     1
# 4                    5.0                   90.9                     1
# ..                   ...                    ...                   ...
# 995                  2.6                   77.0                     6
# 996                  2.9                   86.0                     6
# 997                  3.0                   61.9                     9
# 998                  5.4                  100.0                     1
# 999                  4.3                   89.4                     8
#
#      sleep_hours part_time_job  exam_score
# 0            8.0            No        56.2
# 1            4.6            No       100.0
# 2            8.0            No        34.3
# 3            9.2            No        26.8
# 4            4.9            No        66.4
# ..           ...           ...         ...
# 995          7.5            No        76.1
# 996          6.8           Yes        65.9
# 997          6.5            No        64.4
# 998          7.6           Yes        69.7
# 999          7.1            No        74.9
#
# [909 rows x 6 columns]

# %% [markdown]
# Using Encoding technique to make part_time_job into 0,1 {for true or false as applied}

# %%
le= LabelEncoder()

# %%
df_model['part_time_job'] = le.fit_transform(df_model['part_time_job'])

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  mental_health_rating  \
# 0                    0.0                   85.0                     8
# 1                    6.9                   97.3                     8
# 2                    1.4                   94.8                     1
# 3                    1.0                   71.0                     1
# 4                    5.0                   90.9                     1
# ..                   ...                    ...                   ...
# 995                  2.6                   77.0                     6
# 996                  2.9                   86.0                     6
# 997                  3.0                   61.9                     9
# 998                  5.4                  100.0                     1
# 999                  4.3                   89.4                     8
#
#      sleep_hours  part_time_job  exam_score
# 0            8.0              0        56.2
# 1            4.6              0       100.0
# 2            8.0              0        34.3
# 3            9.2              0        26.8
# 4            4.9              0        66.4
# ..           ...            ...         ...
# 995          7.5              0        76.1
# 996          6.8              1        65.9
# 997          6.5              0        64.4
# 998          7.6              1        69.7
# 999          7.1              0        74.9
#
# [909 rows x 6 columns]

# %%
X = df_model[features]

# %%
y= df_model[target]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
len(y_test)
# Out:
# 182

# %%
len(y_train)
# Out:
# 727

# %%
models = {
    "LinearRegression": {
        "model": LinearRegression(),
        "params": {}
    },
    "DecisionTree": {
        "model": DecisionTreeRegressor(),
        "params": {"max_depth": [3,5,10], "min_samples_split": [2,5]}
    },
    "RandomForest": {
        "model": RandomForestRegressor(),
        "params": {"n_estimators": [50,100], "max_depth": [5,10]}
    }
}

# %%
best_models = []

# %%
for name, config in models.items():
    print(f"Training {name}")

    grid= GridSearchCV(config["model"], config["params"], cv=5, scoring='neg_mean_squared_error')
    grid.fit(X_train, y_train)

    y_pred = grid.predict(X_test)
    rmse= np.sqrt(mean_squared_error(y_test, y_pred))
    r2= r2_score(y_test, y_pred)

    best_models.append({
        "model": name,
        "best_params": grid.best_params_,
        "rmse": rmse,
        "r2": r2
    })
# Out:
# Training LinearRegression
# Training DecisionTree
# Training RandomForest

# %%
best_models
# Out:
# [{'model': 'LinearRegression',
#   'best_params': {},
#   'rmse': np.float64(6.822770487637801),
#   'r2': 0.8032640204565613},
#  {'model': 'DecisionTree',
#   'best_params': {'max_depth': 5, 'min_samples_split': 5},
#   'rmse': np.float64(8.529972528951317),
#   'r2': 0.6924912112928816},
#  {'model': 'RandomForest',
#   'best_params': {'max_depth': 5, 'n_estimators': 100},
#   'rmse': np.float64(7.479920742342868),
#   'r2': 0.7635407761587285}]

# %%
results_df = pd.DataFrame(best_models)

# %%
results_df
# Out:
#               model                               best_params      rmse  \
# 0  LinearRegression                                        {}  6.822770
# 1      DecisionTree  {'max_depth': 5, 'min_samples_split': 5}  8.529973
# 2      RandomForest     {'max_depth': 5, 'n_estimators': 100}  7.479921
#
#          r2
# 0  0.803264
# 1  0.692491
# 2  0.763541

# %%
results_df.sort_values(by='rmse')
# Out:
#               model                               best_params      rmse  \
# 0  LinearRegression                                        {}  6.822770
# 2      RandomForest     {'max_depth': 5, 'n_estimators': 100}  7.479921
# 1      DecisionTree  {'max_depth': 5, 'min_samples_split': 5}  8.529973
#
#          r2
# 0  0.803264
# 2  0.763541
# 1  0.692491

# %%
import joblib

best_row = results_df.sort_values(by='rmse').iloc[0]

# %%
best_row
# Out:
# model          LinearRegression
# best_params                  {}
# rmse                    6.82277
# r2                     0.803264
# Name: 0, dtype: object

# %%
best_model_name = best_row['model']

# %%
best_model_name
# Out:
# 'LinearRegression'

# %%
best_model_config = models[best_model_name]

# %%
best_model_config
# Out:
# {'model': LinearRegression(), 'params': {}}

# %%
final_model = best_model_config['model']

# %%
final_model.fit(X,y)
# Out:
# LinearRegression()

# %%
final_model.predict(X_test)
# Out:
# array([ 76.36598796,  85.58995874,  68.04815179,  50.74268471,
#         70.71589384,  49.74310692,  70.61496485,  62.21932629,
#         82.66920556,  55.50712337,  78.79038574,  76.68472104,
#         47.52966995,  46.24083769,  57.45957817,  67.22882072,
#         54.97205488,  69.95368226,  60.95454931,  82.2417553 ,
#         44.81898792,  68.67625259,  77.76963809,  40.85472813,
#         60.70117069,  56.52867139,  79.55270393,  71.00086671,
#         66.22583241,  57.0472934 ,  66.01137447,  70.24515583,
#         65.04552732,  60.05075545,  84.1404169 ,  75.52807025,
#         56.58691108,  64.17680333,  68.38334944,  79.79071474,
#         87.78875123,  70.40477667,  54.52840609,  61.28183191,
#         74.18329974,  59.13466046,  80.33218451,  84.71786767,
#         78.30936564,  92.69074923,  48.2945095 ,  74.54938602,
#         86.30137744,  74.53698275,  75.5095826 ,  65.24858471,
#         61.46176878,  97.56842667,  59.74918922,  79.09422925,
#         70.05705221,  85.7737938 ,  79.36878895,  80.70978686,
#         66.72764266,  70.6024325 ,  22.90568775,  51.25205314,
#         66.71216009,  74.30904731,  71.53255701,  73.53456232,
#         83.98286524,  32.51965624,  79.37860514,  69.0659914 ,
#         62.76704043,  53.41330638,  83.47702877,  54.8320808 ,
#         80.50391617,  56.9504718 ,  91.99423492,  72.24230521,
#         74.64630704,  81.14151653,  49.2095591 ,  69.35389946,
#         93.96567609,  77.2704704 ,  63.04843369,  58.48066121,
#         83.07636937,  55.5393701 ,  61.85054984,  94.28634195,
#         66.59608214,  83.12680365,  86.19114402,  85.31749649,
#         35.38057943,  58.27705943,  81.17073179,  79.94294863,
#         72.96464702,  73.79670885,  68.93258247,  76.9384696 ,
#         78.93711347,  77.60448884,  75.86463252,  66.55221819,
#         89.69195799,  63.46863323,  68.15955942,  58.56807717,
#         69.44137515,  87.47666446,  81.64018775,  74.91557123,
#         60.29610803,  73.20131605,  73.32456053,  72.6281173 ,
#         81.34776381,  57.98993937,  58.02616961,  60.61304698,
#         63.63790671,  56.25121079,  48.56143345,  54.77872093,
#         66.33382306,  62.15277743,  77.48107335,  83.87763264,
#         49.90983882,  59.16887727,  81.55564529,  66.53984381,
#        100.79359858,  80.08715057,  83.39081928,  67.77673736,
#         53.62059091,  87.76819727,  61.41756477,  92.71797491,
#         63.64137371,  42.46689961,  76.48969124,  72.57702506,
#         63.64001696,  82.51642869,  46.7757078 ,  72.40322861,
#         71.14315062,  47.74082004,  57.8301418 ,  57.8430186 ,
#         57.77560058,  60.44639729,  74.5771561 ,  80.39472169,
#         62.67344973,  74.07300984,  54.55013746,  54.12381522,
#         83.96961185,  96.72667692,  45.36227919,  67.37855373,
#         54.77778489,  68.37208385,  56.6125347 ,  37.5268067 ,
#         97.71483999,  72.22004207,  80.46594508,  51.22222835,
#         57.44638498,  62.0019684 ])

# %%
joblib.dump(final_model, 'best_model.pkl')
# Out:
# ['best_model.pkl']

# %%
joblib.load('best_model.pkl').predict(X_test)
# Out:
# array([ 76.36598796,  85.58995874,  68.04815179,  50.74268471,
#         70.71589384,  49.74310692,  70.61496485,  62.21932629,
#         82.66920556,  55.50712337,  78.79038574,  76.68472104,
#         47.52966995,  46.24083769,  57.45957817,  67.22882072,
#         54.97205488,  69.95368226,  60.95454931,  82.2417553 ,
#         44.81898792,  68.67625259,  77.76963809,  40.85472813,
#         60.70117069,  56.52867139,  79.55270393,  71.00086671,
#         66.22583241,  57.0472934 ,  66.01137447,  70.24515583,
#         65.04552732,  60.05075545,  84.1404169 ,  75.52807025,
#         56.58691108,  64.17680333,  68.38334944,  79.79071474,
#         87.78875123,  70.40477667,  54.52840609,  61.28183191,
#         74.18329974,  59.13466046,  80.33218451,  84.71786767,
#         78.30936564,  92.69074923,  48.2945095 ,  74.54938602,
#         86.30137744,  74.53698275,  75.5095826 ,  65.24858471,
#         61.46176878,  97.56842667,  59.74918922,  79.09422925,
#         70.05705221,  85.7737938 ,  79.36878895,  80.70978686,
#         66.72764266,  70.6024325 ,  22.90568775,  51.25205314,
#         66.71216009,  74.30904731,  71.53255701,  73.53456232,
#         83.98286524,  32.51965624,  79.37860514,  69.0659914 ,
#         62.76704043,  53.41330638,  83.47702877,  54.8320808 ,
#         80.50391617,  56.9504718 ,  91.99423492,  72.24230521,
#         74.64630704,  81.14151653,  49.2095591 ,  69.35389946,
#         93.96567609,  77.2704704 ,  63.04843369,  58.48066121,
#         83.07636937,  55.5393701 ,  61.85054984,  94.28634195,
#         66.59608214,  83.12680365,  86.19114402,  85.31749649,
#         35.38057943,  58.27705943,  81.17073179,  79.94294863,
#         72.96464702,  73.79670885,  68.93258247,  76.9384696 ,
#         78.93711347,  77.60448884,  75.86463252,  66.55221819,
#         89.69195799,  63.46863323,  68.15955942,  58.56807717,
#         69.44137515,  87.47666446,  81.64018775,  74.91557123,
#         60.29610803,  73.20131605,  73.32456053,  72.6281173 ,
#         81.34776381,  57.98993937,  58.02616961,  60.61304698,
#         63.63790671,  56.25121079,  48.56143345,  54.77872093,
#         66.33382306,  62.15277743,  77.48107335,  83.87763264,
#         49.90983882,  59.16887727,  81.55564529,  66.53984381,
#        100.79359858,  80.08715057,  83.39081928,  67.77673736,
#         53.62059091,  87.76819727,  61.41756477,  92.71797491,
#         63.64137371,  42.46689961,  76.48969124,  72.57702506,
#         63.64001696,  82.51642869,  46.7757078 ,  72.40322861,
#         71.14315062,  47.74082004,  57.8301418 ,  57.8430186 ,
#         57.77560058,  60.44639729,  74.5771561 ,  80.39472169,
#         62.67344973,  74.07300984,  54.55013746,  54.12381522,
#         83.96961185,  96.72667692,  45.36227919,  67.37855373,
#         54.77778489,  68.37208385,  56.6125347 ,  37.5268067 ,
#         97.71483999,  72.22004207,  80.46594508,  51.22222835,
#         57.44638498,  62.0019684 ])
